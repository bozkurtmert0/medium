# %% [markdown]
# <a href="https://colab.research.google.com/github/bozkurtmert0/medium/blob/main/Matplotlib2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Matplotlib ile Veri Görselleştirme 2

# %% [markdown]
# Kütüphaneleri dahil edip dizilerimizi oluşturalim

# %%
import numpy as np
import matplotlib.pyplot as plt

a_dizisi = np.linspace(0,10,40)
b_dizisi = a_dizisi **2

# %% [markdown]
# Dizilerimize goz atalim

# %%
print(a_dizisi)
print(b_dizisi)
# Out:
# [ 0.          0.25641026  0.51282051  0.76923077  1.02564103  1.28205128
#   1.53846154  1.79487179  2.05128205  2.30769231  2.56410256  2.82051282
#   3.07692308  3.33333333  3.58974359  3.84615385  4.1025641   4.35897436
#   4.61538462  4.87179487  5.12820513  5.38461538  5.64102564  5.8974359
#   6.15384615  6.41025641  6.66666667  6.92307692  7.17948718  7.43589744
#   7.69230769  7.94871795  8.20512821  8.46153846  8.71794872  8.97435897
#   9.23076923  9.48717949  9.74358974 10.        ]
# [0.00000000e+00 6.57462196e-02 2.62984878e-01 5.91715976e-01
#  1.05193951e+00 1.64365549e+00 2.36686391e+00 3.22156476e+00
#  4.20775805e+00 5.32544379e+00 6.57462196e+00 7.95529257e+00
#  9.46745562e+00 1.11111111e+01 1.28862590e+01 1.47928994e+01
#  1.68310322e+01 1.90006575e+01 2.13017751e+01 2.37343853e+01
#  2.62984878e+01 2.89940828e+01 3.18211703e+01 3.47797502e+01
#  3.78698225e+01 4.10913872e+01 4.44444444e+01 4.79289941e+01
# ...

# %%
plt.plot(a_dizisi,b_dizisi,"r-*")

# %% [markdown]
# # Alt grafikler

# %%
plt.subplot(1,2,1) #kac satir olacagi , kat grafik olacagi ,suan hangisini ciziyo olacagim
plt.plot(a_dizisi,b_dizisi,"g--")
plt.subplot(1,2,2) #2. grafigi cizcegim anlaminda
plt.plot(b_dizisi,a_dizisi,"b-*")

# %% [markdown]
# Figur olusturma
# Ozel sekilde custom grafik olsuturma

# %%
figure1 = plt.figure()  #figure bos canvas gibidir
figure_Axes = figure1.add_axes([0.2,0.2,0.9,0.9]) #0.9 genislik ve yukseklik degeri grafigin
figure_Axes.plot(a_dizisi,b_dizisi,'g')
figure_Axes.set_xlabel('X labeli')
figure_Axes.set_ylabel('y labeli')
figure_Axes.set_title("Baslik")
# Out:
# Text(0.5, 1.0, 'Baslik')

# %% [markdown]
# 2.figure

# %%
figure2 = plt.figure()

eksen1 = figure2.add_axes([0.1,0.1,0.9,0.9])
eksen2 = figure2.add_axes([0.2,0.5,0.3,0.3])  #soldaki 2 arguman sol ve asagidan olan grafigin nerde durdugunu belirler

eksen1.plot(a_dizisi,b_dizisi,"r")
eksen1.set_xlabel("x ekseni")
eksen1.set_ylabel("y ekseni")

eksen1.set_title("Ana grafik ")

#-----------------------kucuk grafik------------------
eksen2.plot(b_dizisi,a_dizisi,"b")
eksen2.set_xlabel("x ekseni")
eksen2.set_ylabel("y ekseni")

eksen2.set_title("alt grafik")
# Out:
# Text(0.5, 1.0, 'alt grafik')

# %%
(figure3 , eksen3) = plt.subplots(nrows =1 ,ncols=2) #tuple seklinde eksenle beraber dondurur 


for eksen in eksen3 :
  eksen.plot(a_dizisi,b_dizisi,"r")
  eksen.set_xlabel("x ekseni")

plt.tight_layout() #grafikler arasi mesafeyi ayarlar
